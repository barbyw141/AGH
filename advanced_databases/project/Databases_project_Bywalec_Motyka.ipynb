# %%
from sqlalchemy import create_engine,Column, Integer, String, Float, ForeignKey, Sequence, CheckConstraint, UniqueConstraint, Date, Table, MetaData,select
from sqlalchemy.ext.declarative import declarative_base
import pandas as pd


db_string = "postgres://postgres:postgres@localhost:5432/slogans"


engine = create_engine(db_string)

Base = declarative_base()

# %%
data = pd.read_csv('input_data.csv', delimiter=';')
data = data.drop('Unnamed: 4', 1)
data
# Out:
#              CATEGORY                   SUBCATEGORY  \
# 0     Apparel slogans  Beachwear & swimwear slogans
# 1     Apparel slogans  Beachwear & swimwear slogans
# 2     Apparel slogans  Beachwear & swimwear slogans
# 3     Apparel slogans  Beachwear & swimwear slogans
# 4     Apparel slogans  Beachwear & swimwear slogans
# ...               ...                           ...
# 5012    Watch slogans                 Watch slogans
# 5013    Watch slogans                 Watch slogans
# 5014    Watch slogans                 Watch slogans
# 5015    Watch slogans                 Watch slogans
# 5016    Watch slogans                 Watch slogans
#
#                                          BRAND  \
# 0                              Speedo Swimwear
# 1                              Speedo Swimwear
# 2                             TA-BOU Beachwear
# 3     Arena, sport swimwear, gear for swimming
# 4     Arena, sport swimwear, gear for swimming
# ...                                        ...
# 5012            Caravelle / Bulova watch brand
# 5013       Accutron / Bulova, swiss-made brand
# 5014       Accutron / Bulova, swiss-made brand
# 5015        Wittnauer / Bulova, luxury watches
# 5016        Wittnauer / Bulova, luxury watches
#
#                                     SLOGAN
# 0                         Fueled by water.
# 1               Speedo. Born in the water.
# 2                    Beachwear competence.
# 3                   Arena. Water instinct.
# 4                    What it takes to win.
# ...                                    ...
# 5012  Caravelle. Great watch. Great price.
# 5013             Accutron. Second to none.
# 5014                Equal Pay, Equal Time.
# 5015            Wittnauer. Into the Night.
# 5016            Passionate about elegance.
#
# [5017 rows x 4 columns]

# %%
# find all unique categories

all_category = data['CATEGORY'].unique()
print("category array: {0}".format(all_category))
# Out:
# category array: ['Apparel slogans' 'Automotive slogans' 'Beauty slogans'
#  'Beverage slogans' 'Business slogans' 'Construction slogans'
#  'Dining slogans' 'Educational slogans' 'Financial service slogans'
#  'Casino slogans' 'Computers slogans' 'Condoms slogans'
#  'Magagines slogans' 'Motorcycle slogans' 'Newspapers slogans'
#  'Pet food slogans' 'Radio stations slogans' 'Real estate slogans'
#  'Tobacco slogans' 'Vitamins slogans' 'Watch slogans']

# %%
category_list = pd.DataFrame(all_category, columns=['category'])

category_list.index.name = 'id'

category_list
# Out:
#                      category
# id
# 0             Apparel slogans
# 1          Automotive slogans
# 2              Beauty slogans
# 3            Beverage slogans
# 4            Business slogans
# 5        Construction slogans
# 6              Dining slogans
# 7         Educational slogans
# 8   Financial service slogans
# 9              Casino slogans
# 10          Computers slogans
# 11            Condoms slogans
# 12          Magagines slogans
# 13         Motorcycle slogans
# 14         Newspapers slogans
# 15           Pet food slogans
# 16     Radio stations slogans
# 17        Real estate slogans
# 18            Tobacco slogans
# 19           Vitamins slogans
# 20              Watch slogans

# %%
# find all unique subcategories

all_subcategory = data['SUBCATEGORY'].unique()
print("subcategory array: {0}".format(all_subcategory))
# Out:
# subcategory array: ['Beachwear & swimwear slogans' 'Clothing brand slogans'
#  'Fur clothing slogans' 'Jeans slogans' 'Shoes slogans' 'Socks slogans'
#  'Uniform & workwear slogans' 'Underwear slogans'
#  'Auto goods, parts, accessories slogans' 'Car brand slogans'
#  'Car dealer slogans' 'Car slogans' 'Car rental slogans'
#  'Car tuning slogans' 'Car wash slogans' 'Driving school slogans'
#  'Tire slogans' 'Wheel slogans' 'Barber shop slogans'
#  'Beauty salon slogans' 'Advertising slogans for eye makeup, mascara.'
#  'Hair care product slogans' 'Hair salon slogans'
#  'Advertising slogans for lip makeup, lipstick, lip gloss.'
#  'Makeup brands.' 'Tanning salon slogans' 'Tattoo shop slogans'
#  'Alcoholic drink slogans' 'Bottled water slogans'
#  'Carbonated drink slogans' 'Coffee slogans' 'Energy drink slogans'
#  'Iced tea & coffee slogans' 'Juice slogans' 'Sports drink slogans'
#  'Tea slogans' 'Advertising agency slogans'
#  'Answering service & call center slogans' 'Branding company slogans'
#  'Business consulting slogans' 'Cleaning slogans' 'Copywriting slogans'
#  'Graphic design slogans' 'HR service slogans' 'Marketing company slogans'
#  'Naming slogans' 'Office supplies slogans' 'PR agency slogans'
#  'Printing company slogans' 'Security company slogans'
#  'Translation services slogans' 'Web design slogans'
#  'Door & window slogans' 'Drywall company slogans' 'Floor slogans'
#  'Paint slogans' 'Painting company slogans' 'Roofing company slogans'
#  'Tool slogans' 'Bakery slogans' 'Bar & grill slogans'
#  'Cakery, cake shop slogans' 'Catering slogans' 'Coffee shop slogans'
#  'Fast food slogans' 'Fish and chips slogans' 'Ice cream shop slogans'
#  'Restaurant slogans' 'Business school slogans' 'College slogans'
#  'Distance education' 'IT training & certification' 'Law school slogans'
#  'Learning disability schools' 'Library slogans' 'Medical school slogans'
#  'Tutoring slogans' 'University slogans' 'Bank slogans'
#  'Credit card slogans' 'Factoring slogans' 'Insurance company slogans'
#  'Leasing slogans' 'Money transfer slogans' 'Mortgage slogans'
#  'Casino slogans' 'Computer brands slogans' 'Software slogans'
#  'Condoms slogans' 'Magagines slogans' 'Motorcycle slogans'
#  'Newspapers slogans' 'Pet food slogans' 'Radio stations slogans'
#  'Real estate slogans' 'Cigarettes slogans' 'Cigars slogans'
#  'Smoking accessories slogans' 'Vitamins slogans' 'Watch slogans']

# %%
# subcategory, connected to category

subcategory_list = data[['CATEGORY','SUBCATEGORY']].drop_duplicates().reset_index().drop(columns = ['index']);
subcategory_list.index.name = 'id'

subcategory_list = subcategory_list.rename(columns = {'CATEGORY':'category_id'})
subcategory_list = subcategory_list.rename(columns = {'SUBCATEGORY':'subcategory'})

subcategory_list['category_id'] = subcategory_list['category_id'].map(lambda x:  category_list[category_list['category'] == x].index.values.astype(int)[0])

pd.set_option('display.max_rows', 100)
subcategory_list
# Out:
#     category_id                                        subcategory
# id
# 0             0                       Beachwear & swimwear slogans
# 1             0                             Clothing brand slogans
# 2             0                               Fur clothing slogans
# 3             0                                      Jeans slogans
# 4             0                                      Shoes slogans
# 5             0                                      Socks slogans
# 6             0                         Uniform & workwear slogans
# 7             0                                  Underwear slogans
# 8             1             Auto goods, parts, accessories slogans
# 9             1                                  Car brand slogans
# 10            1                                 Car dealer slogans
# 11            1                                        Car slogans
# 12            1                                 Car rental slogans
# 13            1                                 Car tuning slogans
# 14            1                                   Car wash slogans
# 15            1                             Driving school slogans
# 16            1                                       Tire slogans
# 17            1                                      Wheel slogans
# 18            2                                Barber shop slogans
# 19            2                               Beauty salon slogans
# 20            2       Advertising slogans for eye makeup, mascara.
# 21            2                          Hair care product slogans
# 22            2                                 Hair salon slogans
# 23            2  Advertising slogans for lip makeup, lipstick, ...
# 24            2                                     Makeup brands.
# 25            2                              Tanning salon slogans
# 26            2                                Tattoo shop slogans
# 27            3                            Alcoholic drink slogans
# 28            3                              Bottled water slogans
# 29            3                           Carbonated drink slogans
# 30            3                                     Coffee slogans
# 31            3                               Energy drink slogans
# 32            3                          Iced tea & coffee slogans
# 33            3                                      Juice slogans
# 34            3                               Sports drink slogans
# 35            3                                        Tea slogans
# 36            4                         Advertising agency slogans
# 37            4            Answering service & call center slogans
# 38            4                           Branding company slogans
# 39            4                        Business consulting slogans
# 40            4                                   Cleaning slogans
# 41            4                                Copywriting slogans
# 42            4                             Graphic design slogans
# 43            4                                 HR service slogans
# 44            4                          Marketing company slogans
# 45            4                                     Naming slogans
# 46            4                            Office supplies slogans
# 47            4                                  PR agency slogans
# 48            4                           Printing company slogans
# 49            4                           Security company slogans
# 50            4                       Translation services slogans
# 51            4                                 Web design slogans
# 52            5                              Door & window slogans
# 53            5                            Drywall company slogans
# 54            5                                      Floor slogans
# 55            5                                      Paint slogans
# 56            5                           Painting company slogans
# 57            5                            Roofing company slogans
# 58            5                                       Tool slogans
# 59            6                                     Bakery slogans
# 60            6                                Bar & grill slogans
# 61            6                          Cakery, cake shop slogans
# 62            6                                   Catering slogans
# 63            6                                Coffee shop slogans
# 64            6                                  Fast food slogans
# 65            6                             Fish and chips slogans
# 66            6                             Ice cream shop slogans
# 67            6                                 Restaurant slogans
# 68            7                            Business school slogans
# 69            7                                    College slogans
# 70            7                                 Distance education
# 71            7                        IT training & certification
# 72            7                                 Law school slogans
# 73            7                        Learning disability schools
# 74            7                                    Library slogans
# 75            7                             Medical school slogans
# 76            7                                   Tutoring slogans
# 77            7                                 University slogans
# 78            8                                       Bank slogans
# 79            8                                Credit card slogans
# 80            8                                  Factoring slogans
# 81            8                          Insurance company slogans
# 82            8                                    Leasing slogans
# 83            8                             Money transfer slogans
# 84            8                                   Mortgage slogans
# 85            9                                     Casino slogans
# 86           10                            Computer brands slogans
# 87           10                                   Software slogans
# 88           11                                    Condoms slogans
# 89           12                                  Magagines slogans
# 90           13                                 Motorcycle slogans
# 91           14                                 Newspapers slogans
# 92           15                                   Pet food slogans
# 93           16                             Radio stations slogans
# 94           17                                Real estate slogans
# 95           18                                 Cigarettes slogans
# 96           18                                     Cigars slogans
# 97           18                        Smoking accessories slogans
# 98           19                                   Vitamins slogans
# 99           20                                      Watch slogans

# %%
# find all unique brands

all_brand = data['BRAND'].unique()
print("brand array: {0}".format(all_brand))
# Out:
# brand array: ['Speedo Swimwear' 'TA-BOU Beachwear'
#  'Arena, sport swimwear, gear for swimming' ...
#  'Caravelle / Bulova watch brand' 'Accutron / Bulova, swiss-made brand'
#  'Wittnauer / Bulova, luxury watches']

# %%
brand_list = pd.DataFrame(all_brand, columns=['brand'])

brand_list.index.name = 'id'

brand_list
# Out:
#                                          brand
# id
# 0                              Speedo Swimwear
# 1                             TA-BOU Beachwear
# 2     Arena, sport swimwear, gear for swimming
# 3       Arena Bodylift, body shaping swimsuits
# 4                                 TYR Swimwear
# ...                                        ...
# 3898           Bulova, watch and clock company
# 3899                        Bulova watch brand
# 3900            Caravelle / Bulova watch brand
# 3901       Accutron / Bulova, swiss-made brand
# 3902        Wittnauer / Bulova, luxury watches
#
# [3903 rows x 1 columns]

# %%
# find all slogans

all_slogan = data['SLOGAN'].unique()
print("slogan array: {0}".format(all_slogan))
# Out:
# slogan array: ['Fueled by water.' 'Speedo. Born in the water.' 'Beachwear competence.'
#  ... 'Equal Pay, Equal Time.' 'Wittnauer. Into the Night.'
#  'Passionate about elegance.']

# %%
# slogan, connected to subcategory and brand

slogan_list = data[['SUBCATEGORY','BRAND','SLOGAN']].drop_duplicates().reset_index().drop(columns = ['index']);
slogan_list.index.name = 'id'

slogan_list = slogan_list.rename(columns = {'SUBCATEGORY':'subcategory_id'})
slogan_list = slogan_list.rename(columns = {'BRAND':'brand_id'})
slogan_list = slogan_list.rename(columns = {'SLOGAN':'slogan'})

slogan_list['subcategory_id'] = slogan_list['subcategory_id'].map(lambda x:  subcategory_list[subcategory_list['subcategory'] == x].index.values.astype(int)[0])
slogan_list['brand_id'] = slogan_list['brand_id'].map(lambda x:  brand_list[brand_list['brand'] == x].index.values.astype(int)[0])

slogan_list
# Out:
#       subcategory_id  brand_id                                slogan
# id
# 0                  0         0                      Fueled by water.
# 1                  0         0            Speedo. Born in the water.
# 2                  0         1                 Beachwear competence.
# 3                  0         2                Arena. Water instinct.
# 4                  0         2                 What it takes to win.
# ...              ...       ...                                   ...
# 5012              99      3900  Caravelle. Great watch. Great price.
# 5013              99      3901             Accutron. Second to none.
# 5014              99      3901                Equal Pay, Equal Time.
# 5015              99      3902            Wittnauer. Into the Night.
# 5016              99      3902            Passionate about elegance.
#
# [5017 rows x 3 columns]

# %%
#Table definition and insert data

class category(Base):
    __tablename__ = 'category'
    __table_args__ = (
        UniqueConstraint('category'),
    )
    id = Column(Integer, Sequence('seq_category_id'), primary_key = True)
    category = Column(String(50))

class subcategory(Base):
    __tablename__ = 'subcategory'
    __table_args__ = (
        UniqueConstraint('subcategory'),
    )
    id = Column(Integer, Sequence('seq_subcategory_id'), primary_key=True)
    category_id=Column(Integer, ForeignKey('category.id'))
    subcategory = Column(String(100))

class brand(Base):
    __tablename__ = 'brand'
    __table_args__ = (
        UniqueConstraint('brand'),
    )
    id = Column(Integer, Sequence('seq_brand_id'), primary_key = True)
    brand = Column(String(200))

class slogan(Base):
    __tablename__ = 'slogan'
    id = Column(Integer,Sequence('seq_slogan_id'),  primary_key=True)
    slogan =Column(String(200))
    subcategory_id=Column(Integer, ForeignKey('subcategory.id'))
    brand_id=Column(Integer, ForeignKey('brand.id'))
    
Base.metadata.create_all(engine)

# %%
category_list.to_sql('category',engine, if_exists='append')
subcategory_list.to_sql('subcategory',engine, if_exists='append')
brand_list.to_sql('brand',engine, if_exists='append')
slogan_list.to_sql('slogan',engine, if_exists='append')

# %%
#initialize mapper operation
metadata = MetaData()

dic_table = {}
for table_name in engine.table_names():
    dic_table[table_name] = Table(table_name, metadata , autoload=True, autoload_with=engine)

# %%
# wszystkie kategorie
mapper_stmt = select([dic_table['category'].columns.id,dic_table['category'].columns.category])
print('Mapper select: ')
print(mapper_stmt)
mapper_results = engine.execute(mapper_stmt).fetchall()
print(mapper_results)
print('\nIlosc kategorii:')
len(mapper_results)
# Out:
# Mapper select:
# SELECT category.id, category.category
# FROM category
# [(0, 'Apparel slogans'), (1, 'Automotive slogans'), (2, 'Beauty slogans'), (3, 'Beverage slogans'), (4, 'Business slogans'), (5, 'Construction slogans'), (6, 'Dining slogans'), (7, 'Educational slogans'), (8, 'Financial service slogans'), (9, 'Casino slogans'), (10, 'Computers slogans'), (11, 'Condoms slogans'), (12, 'Magagines slogans'), (13, 'Motorcycle slogans'), (14, 'Newspapers slogans'), (15, 'Pet food slogans'), (16, 'Radio stations slogans'), (17, 'Real estate slogans'), (18, 'Tobacco slogans'), (19, 'Vitamins slogans'), (20, 'Watch slogans')]
#
# Ilosc kategorii:
# 21

# %%
# wszystkie slogany z kategorii Automotive slogans
mapper_stmt = select([dic_table['slogan'].columns.slogan]).\
    where(dic_table['slogan'].columns.subcategory_id.in_(select([dic_table['subcategory'].columns.id]).\
         where(dic_table['subcategory'].columns.category_id.in_(select([dic_table['category'].columns.id]).\
             where(dic_table['category'].columns.category == 'Automotive slogans' )))))
print('Mapper select: ')
print(mapper_stmt)
mapper_results = engine.execute(mapper_stmt).fetchall()
print(mapper_results)
# Out:
# Mapper select:
# SELECT slogan.slogan
# FROM slogan
# WHERE slogan.subcategory_id IN (SELECT subcategory.id
# FROM subcategory
# WHERE subcategory.category_id IN (SELECT category.id
# FROM category
# WHERE category.category = :category_1))
# [('Blaupunkt. The advantage in your car.',), ('Kenwood. Listen to the Future.',), ('Rockford Fosgate. Car audio for fanatics.',), ('Volfenhag. A German Concept.',), ("Kicker. Fuel for Livin' Loud!",), ('Not just oil, Pennzoil.',), ('Havoline. Add More Life to Your Car.',), ("Mobil 1. The oil that's changing oil.",), ('Unlike any other.',), ('Mercedes-Benz. The Future of the Automobile.',), ('Engineered to move the human spirit.',), ('The Power of Dreams.',), ('It must be love.',), ('Honda. First man, then machine.',), ('Technology you can enjoy.',), ('The True Definition of Luxury. Yours.',), (' Acura. Precision Crafted Performance.',), ('Driven by passion. FIAT.',), ('Alfa Romeo. Beauty is not enough.',), ('Power for your control.',), ('Volvo. For life.',), ('Subaru. Think. Feel. Drive.',), ("Driven By What's Inside.",), ('When You Get It, You Get It.',), ('The Beauty of All-Wheel Drive.',), ('Ford. Feel the difference.',), ('  Ford. Bold moves.(USA)',), (' Built for life in Canada.(Canada)',), (' Built for the road ahead.',), ('  Ford. Designed for living. Engineered to last.',), ('  Have you driven a Ford lately?',), ('Infiniti. Accelerating the Future.',), ('BMW. The Ultimate Driving Machine.',), ('BMW. Sheer Driving Pleasure.',), ('The Ultimate Driving Experience.',), ('Born to perform.',), ('\u2003Unleash a Jaguar.',), ("\u2003Don't dream it. Drive it!",), ('\u2003Jaguar. The art of performance.',), ('\u2003Grace.... space... pace.',), ('Keeping ahead through technology.',), ('\u2003\u2003\u2003\u2003\u2003\u2003\u2003\u2003\u2003Everyone dreams of an Audi.',), ('Volkswagen. Drivers wanted.',), ('For the love of the car.',), ('Relieves gas pains.',), ('Surprisingly ordinary prices',), ('Peugeot. Live the pleasure.',), ('\u2003\u2003\u2003\u2003\u2003\u2003\u2003\u2003\u2003The drive of your life.',), ('\u2003\u2003\u2003\u2003\u2003\u2003\u2003\u2003\u2003The lion goes from strength to strength.',), ("Jeep. There's Only One.",), ("Let's go places.",), ('Today tomorrow Toyota.(Europe)',), ('Toyota. Moving forward.',), ('The best built cars in the world.',), ('Get the feeling!',), ('Everyday.',), ('Drive your dreams.',), ('The car in front is a Toyota.',), ('I love what you do for me, Toyota!',), ('Who could ask for anything more?',), ('Oh, what a feeling!',), ('You asked for it! You got it!',), ('Your new experience of motoring.',), ('We are driving excitement.',), ('Rover. A Class Of Its Own.',), ('Land Rover. Go beyond.',), ('Chevrolet. An American Revolution',), ('See the USA in your Chevrolet',), ('The Heartbeat of America',), ("The road isn't built that can make it breathe hard!",), ('Eye it - try it - buy it!',), ('Hyundai. Drive your way',), ('Always There for You',), ('Driving is believing',), ('Prepare to want one',), ('Shift',), ('Shift expectations.',), ('You can with a Nissan.',), ('Just wait you drive it.',), ('Drive & Love',), ('Chrysler. Drive = Love',), ('Chrysler. Inspiration comes standard',), ('Kia. The Power to Surprise',), ('Make every mile count(USA campaign)',), ('The Car that Cares',), ('The Passionate Pursuit of Perfection',), ('The Relentless Pursuit of Perfection',), ('Porsche, There is No Substitute',), ('Skoda. Simply Clever',), ("It's a Skoda. Honest.",), ('Start Something.',), ("This is not your father's Oldsmobile.",), ('Cadillac. Break Through.',), ('Creating a Higher Standard.',), ('Standard of the World.',), ('The Penalty of Leadership.',), ('Dodge. Grab Life by the Horns.',), ('Dodge. Different.',), ('Dream Up.',), ("Buick. It's All Good.",), ("Isn't it time for a real car?",), ('Buick. The spirit of American style.',), ('New Doors Opened.',), ('Imagine Yourself in a Mercury now.',), ('Welcome to the State of Independence',), ('Saab. Move your mind',), ('Find Your Own Road.',), ('Smart. Open your mind.',), ('Lincoln. Travel Well.',), ('What a Luxury Car Should Be.',), ('Hummer. Like Nothing Else.',), ('Holden go.',), ('Seat. Auto emocion.',), ('Saturn. Like always. Like never before.',) ...
